# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('train_ship.csv'  )

# %%
df.head()
# Out:
#             Customer Id     Artist Name  Artist Reputation  Height  Width  \
# 0  fffe3900350033003300   Billy Jenkins               0.26    17.0    6.0
# 1  fffe3800330031003900     Jean Bryant               0.28     3.0    3.0
# 2  fffe3600370035003100    Laura Miller               0.07     8.0    5.0
# 3      fffe350031003300  Robert Chaires               0.12     9.0    NaN
# 4  fffe3900320038003400    Rosalyn Krol               0.15    17.0    6.0
#
#    Weight   Material  Price Of Sculpture  Base Shipping Price International  \
# 0  4128.0      Brass               13.91                16.27           Yes
# 1    61.0      Brass                6.83                15.00            No
# 2   237.0       Clay                4.96                21.18            No
# 3     NaN  Aluminium                5.81                16.31            No
# 4   324.0  Aluminium                3.18                11.94           Yes
#
#   Express Shipment Installation Included Transport Fragile  \
# ...

# %%
df.tail()
# Out:
#                Customer Id          Artist Name  Artist Reputation  Height  \
# 6495  fffe3800370037003300  Jeffrey Freudenthal               0.37    37.0
# 6496      fffe310036003400        Larry Edwards               0.67    15.0
# 6497  fffe3600300031003300         Denise Worth               0.68    19.0
# 6498  fffe3600350035003900          Daniel Drew               0.02    33.0
# 6499  fffe3700310031003600       Vernon Carroll               0.18    30.0
#
#       Width     Weight Material  Price Of Sculpture  Base Shipping Price  \
# 6495   10.0    16551.0    Brass               28.28                38.46
# 6496    NaN    18981.0      NaN               67.18                27.72
# 6497    8.0      587.0     Clay                6.92                10.38
# 6498    9.0  1269377.0    Stone             2929.13                69.76
# 6499   13.0    34729.0    Brass               46.63                78.25
#
# ...

# %%
df['Artist Name']
# Out:
# 0             Billy Jenkins
# 1               Jean Bryant
# 2              Laura Miller
# 3            Robert Chaires
# 4              Rosalyn Krol
#                ...
# 6495    Jeffrey Freudenthal
# 6496          Larry Edwards
# 6497           Denise Worth
# 6498            Daniel Drew
# 6499         Vernon Carroll
# Name: Artist Name, Length: 6500, dtype: object

# %%
df['Artist Name'][0]
# Out:
# 'Billy Jenkins'

# %%
df.iloc[0]
# Out:
# Customer Id                fffe3900350033003300
# Artist Name                       Billy Jenkins
# Artist Reputation                          0.26
# Height                                       17
# Width                                         6
# Weight                                     4128
# Material                                  Brass
# Price Of Sculpture                        13.91
# Base Shipping Price                       16.27
# International                               Yes
# Express Shipment                            Yes
# Installation Included                        No
# Transport                               Airways
# Fragile                                      No
# Customer Information              Working Class
# Remote Location                              No
# Scheduled Date                         06/07/15
# Delivery Date                          06/03/15
# Customer Location        New Michelle, OH 50777
# Cost                                    -283.29
# ...

# %%
df.iloc[: , 1]
# Out:
# 0             Billy Jenkins
# 1               Jean Bryant
# 2              Laura Miller
# 3            Robert Chaires
# 4              Rosalyn Krol
#                ...
# 6495    Jeffrey Freudenthal
# 6496          Larry Edwards
# 6497           Denise Worth
# 6498            Daniel Drew
# 6499         Vernon Carroll
# Name: Artist Name, Length: 6500, dtype: object

# %%
df.iloc[:3, 1]
# Out:
# 0    Billy Jenkins
# 1      Jean Bryant
# 2     Laura Miller
# Name: Artist Name, dtype: object

# %%
df.iloc[1:3, 0]
# Out:
# 1    fffe3800330031003900
# 2    fffe3600370035003100
# Name: Customer Id, dtype: object

# %%
df.iloc[-5:]
# Out:
#                Customer Id          Artist Name  Artist Reputation  Height  \
# 6495  fffe3800370037003300  Jeffrey Freudenthal               0.37    37.0
# 6496      fffe310036003400        Larry Edwards               0.67    15.0
# 6497  fffe3600300031003300         Denise Worth               0.68    19.0
# 6498  fffe3600350035003900          Daniel Drew               0.02    33.0
# 6499  fffe3700310031003600       Vernon Carroll               0.18    30.0
#
#       Width     Weight Material  Price Of Sculpture  Base Shipping Price  \
# 6495   10.0    16551.0    Brass               28.28                38.46
# 6496    NaN    18981.0      NaN               67.18                27.72
# 6497    8.0      587.0     Clay                6.92                10.38
# 6498    9.0  1269377.0    Stone             2929.13                69.76
# 6499   13.0    34729.0    Brass               46.63                78.25
#
# ...

# %%
# to find what is Present at the 0 index of Particular Columns
df.loc[0, 'Artist Name']
# Out:
# 'Billy Jenkins'

# %%
df.loc[:, ['Artist Name', 'Artist Reputation', 'Artist Reputation']]
# Out:
#               Artist Name  Artist Reputation  Artist Reputation
# 0           Billy Jenkins               0.26               0.26
# 1             Jean Bryant               0.28               0.28
# 2            Laura Miller               0.07               0.07
# 3          Robert Chaires               0.12               0.12
# 4            Rosalyn Krol               0.15               0.15
# ...                   ...                ...                ...
# 6495  Jeffrey Freudenthal               0.37               0.37
# 6496        Larry Edwards               0.67               0.67
# 6497         Denise Worth               0.68               0.68
# 6498          Daniel Drew               0.02               0.02
# 6499       Vernon Carroll               0.18               0.18
#
# [6500 rows x 3 columns]

# %% [markdown]
# Manipulating the index

# %%
df.Material == 'Brass'
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 6495     True
# 6496    False
# 6497    False
# 6498    False
# 6499     True
# Name: Material, Length: 6500, dtype: bool

# %%
df.loc[df.Material == 'Brass']
# Out:
#                Customer Id          Artist Name  Artist Reputation  Height  \
# 0     fffe3900350033003300        Billy Jenkins               0.26    17.0
# 1     fffe3800330031003900          Jean Bryant               0.28     3.0
# 6     fffe3800360033003700          David Hawes               0.64    17.0
# 14        fffe310033003100    Patricia Crosslin               0.69    21.0
# 26    fffe3400350031003200          Chris Gomez               0.20    25.0
# ...                    ...                  ...                ...     ...
# 6455  fffe3900350032003700     Lucille Williams               0.96     9.0
# 6458  fffe3300380032003700       Donald Mullins                NaN    31.0
# 6475  fffe3400370034003500         John Wilkins               0.63    12.0
# 6495  fffe3800370037003300  Jeffrey Freudenthal               0.37    37.0
# 6499  fffe3700310031003600       Vernon Carroll               0.18    30.0
#
# ...

# %%
# finding the material Brass which having width > 9 
df.loc[(df.Material == 'Brass') & (df.Width >= 9)]
# Out:
#                Customer Id          Artist Name  Artist Reputation  Height  \
# 6     fffe3800360033003700          David Hawes               0.64    17.0
# 26    fffe3400350031003200          Chris Gomez               0.20    25.0
# 38    fffe3900320032003700     Magdalena Jordan               0.59    22.0
# 42    fffe3400390034003300    George Trovillion               0.86    49.0
# 95    fffe3300350037003500       Charles Decker                NaN    35.0
# ...                    ...                  ...                ...     ...
# 6431  fffe3600320035003100       Monique Brooks               0.78    22.0
# 6442  fffe3700330035003400      Thomas Spengler               0.24    37.0
# 6443  fffe3800310038003200     Willie Benscoter               0.63    43.0
# 6495  fffe3800370037003300  Jeffrey Freudenthal               0.37    37.0
# 6499  fffe3700310031003600       Vernon Carroll               0.18    30.0
#
# ...

# %%
df.loc[(df.Material == 'Brass') | (df.Width >= 9)]
# Out:
#                Customer Id          Artist Name  Artist Reputation  Height  \
# 0     fffe3900350033003300        Billy Jenkins               0.26    17.0
# 1     fffe3800330031003900          Jean Bryant               0.28     3.0
# 5     fffe3300390039003900        Tracy Francis               0.99    46.0
# 6     fffe3800360033003700          David Hawes               0.64    17.0
# 7     fffe3800300039003800          David Osher               0.74    23.0
# ...                    ...                  ...                ...     ...
# 6492  fffe3800350039003100      Tiffanie Moreno               0.80    17.0
# 6494  fffe3300370030003500         Karen Bayles               0.45     NaN
# 6495  fffe3800370037003300  Jeffrey Freudenthal               0.37    37.0
# 6498  fffe3600350035003900          Daniel Drew               0.02    33.0
# 6499  fffe3700310031003600       Vernon Carroll               0.18    30.0
#
# ...

# %%
df.loc[df.Material.isin(['Brass', 'Wood'])]
# Out:
#                Customer Id          Artist Name  Artist Reputation  Height  \
# 0     fffe3900350033003300        Billy Jenkins               0.26    17.0
# 1     fffe3800330031003900          Jean Bryant               0.28     3.0
# 5     fffe3300390039003900        Tracy Francis               0.99    46.0
# 6     fffe3800360033003700          David Hawes               0.64    17.0
# 13    fffe3400370033003400          James Davis               0.54    26.0
# ...                    ...                  ...                ...     ...
# 6484  fffe3600370038003300    Myles Fitzpatrick               0.45    16.0
# 6487  fffe3200350033003500         Lloyd Sartin               0.38    30.0
# 6493      fffe350037003800        William Curry                NaN    13.0
# 6495  fffe3800370037003300  Jeffrey Freudenthal               0.37    37.0
# 6499  fffe3700310031003600       Vernon Carroll               0.18    30.0
#
# ...

# %%
df.describe()
# Out:
#        Artist Reputation       Height        Width        Weight  \
# count        5750.000000  6125.000000  5916.000000  5.913000e+03
# mean            0.461850    21.766204     9.617647  4.006948e+05
# std             0.265781    11.968192     5.417000  2.678081e+06
# min             0.000000     3.000000     2.000000  3.000000e+00
# 25%             0.240000    12.000000     6.000000  5.030000e+02
# 50%             0.450000    20.000000     8.000000  3.102000e+03
# 75%             0.680000    30.000000    12.000000  3.645600e+04
# max             1.000000    73.000000    50.000000  1.179279e+08
#
#        Price Of Sculpture  Base Shipping Price          Cost
# count          6500.00000          6500.000000  6.500000e+03
# mean           1192.42009            37.407174  1.713920e+04
# std            8819.61675            26.873519  2.406579e+05
# min               3.00000            10.000000 -8.801727e+05
# 25%               5.23000            16.700000  1.884400e+02
# ...

# %%
# mean for Particular Columns
df['Height'].mean()
# Out:
# 21.766204081632655

# %%
df['Width'].mean()
# Out:
# 9.617647058823529

# %%
df['Weight'].mean()
# Out:
# 400694.8219178082

# %%
# to see unique function
df['Material'].unique()
# Out:
# array(['Brass', 'Clay', 'Aluminium', 'Wood', 'Marble', 'Bronze', 'Stone',
#        nan], dtype=object)

# %%
df['Material'].value_counts()
# Out:
# Brass        847
# Aluminium    845
# Bronze       821
# Marble       819
# Wood         816
# Clay         816
# Stone        772
# Name: Material, dtype: int64

# %%
df.groupby('Weight').Width.count()
# Out:
# Weight
# 3.0            0
# 4.0            2
# 5.0            2
# 6.0            2
# 8.0            3
#               ..
# 47544217.0     1
# 47717848.0     1
# 49145353.0     1
# 53118478.0     1
# 117927869.0    1
# Name: Width, Length: 4410, dtype: int64
